# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql:///Source')

# %%
query = '''SELECT * FROM movies'''
df = pd.read_sql(query, engine)

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.sample(5)
# Out:
#      Unnamed: 0                                        Poster_Link  \
# 899         898  https://m.media-amazon.com/images/M/MV5BMTgwOD...
# 758         757  https://m.media-amazon.com/images/M/MV5BOTY4NT...
# 198         197  https://m.media-amazon.com/images/M/MV5BZGRkOG...
# 966         966  https://m.media-amazon.com/images/M/MV5BNjEzYj...
# 621         617  https://m.media-amazon.com/images/M/MV5BYWUxZj...
#
#                        Series_Title Released_Year Certificate  Runtime  \
# 899  Dawn of the Planet of the Apes          2014          UA  130 min
# 758                     Frost/Nixon          2008           R  122 min
# 198                  Koe no katachi          2016          16  130 min
# 966                       Apollo 13            PG           U  140 min
# 621                            Once          2007           R   86 min
#
#                          Genre  IMDB_Rating  \
# 899   Action, Adventure, Drama          7.6
# 758  Biography, Drama, History          7.7
# 198   Animation, Drama, Family          8.1
# 966  Adventure, Drama, History          7.6
# 621      Drama, Music, Romance          7.8
#
#                                               Overview  Meta_score  \
# 899  A growing nation of genetically evolved apes l...        79.0
# 758  A dramatic retelling of the post-Watergate tel...        80.0
# 198  A young man is ostracized by his classmates af...        78.0
# 966  NASA must devise a strategy to return Apollo 1...        77.0
# 621  A modern-day musical about a busker and an imm...        88.0
#
#          Director           Star1            Star2        Star3  \
# 899   Matt Reeves     Gary Oldman     Keri Russell  Andy Serkis
# 758    Ron Howard  Frank Langella    Michael Sheen  Kevin Bacon
# 198  Naoko Yamada      Miyu Irino     Saori Hayami     Aoi Yûki
# 966    Ron Howard       Tom Hanks      Bill Paxton  Kevin Bacon
# 621   John Carney    Glen Hansard  Markéta Irglová   Hugh Walsh
#
#                 Star4  No_of_Votes        Gross
# 899  Kodi Smit-McPhee       411599  208,545,589
# 758      Sam Rockwell       103330   18,593,156
# 198        Kenshô Ono        47708         None
# 966       Gary Sinise       269197  173,837,933
# 621   Gerard Hendrick       110656    9,439,923

# %% [markdown]
# # Data Restructuring

# %% [markdown]
# 1. Break up comma-separated values into separate rows.

# %%
for col in df:
    if df[col].astype(str).str.contains(',').any():
        print (col)
# Out:
# Poster_Link
# Series_Title
# Genre
# Overview
# Gross

# %%
df[['Poster_Link', 'Series_Title', 'Overview', 'Gross']].head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2           The Dark Knight
# 3    The Godfather: Part II
# 4              12 Angry Men
#
#                                             Overview        Gross
# 0  Two imprisoned men bond over a number of years...   28,341,469
# 1  An organized crime dynasty's aging patriarch t...  134,966,411
# 2  When the menace known as the Joker wreaks havo...  534,858,444
# 3  The early life and career of Vito Corleone in ...   57,300,000
# 4  A jury holdout attempts to prevent a miscarria...    4,360,000

# %% [markdown]
# Investigation shows that Genre is the only column with multiple values, all other columns have commas for acceptable reasons, therefore value separation will be done for the Genre column alone.

# %%
df['Genre'] = df['Genre'].str.split(',')
df = df.explode('Genre')
# It good practice to additionally strip the exploded column, this removes whitespaces that can create fake duplicates.
# For example 'Drama' and ' Drama' won't be detected as duplicates and will cause issues later in the pipeline.
df['Genre'] = df['Genre'].str.strip()

# %%
df.head(10)
# Out:
#    Unnamed: 0                                        Poster_Link  \
# 0           0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1           1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 1           1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2           2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2           2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2           2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3           3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 3           3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4           4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 4           4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime   Genre  \
# 0  The Shawshank Redemption          1994           A  142 min   Drama
# 1             The Godfather          1972           A  175 min   Crime
# 1             The Godfather          1972           A  175 min   Drama
# 2           The Dark Knight          2008          UA  152 min  Action
# 2           The Dark Knight          2008          UA  152 min   Crime
# 2           The Dark Knight          2008          UA  152 min   Drama
# 3    The Godfather: Part II          1974           A  202 min   Crime
# 3    The Godfather: Part II          1974           A  202 min   Drama
# 4              12 Angry Men          1957           U   96 min   Crime
# 4              12 Angry Men          1957           U   96 min   Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 3          9.0  The early life and career of Vito Corleone in ...        90.0
# 3          9.0  The early life and career of Vito Corleone in ...        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 2   Michael Caine      2303232  534,858,444
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# 2. Check for repeating columns of the same attribute.
#
# Printing the list of columns alphabetically makes this easier to spot.

# %%
df.dtypes.sort_index()
# Out:
# Certificate       object
# Director          object
# Genre             object
# Gross             object
# IMDB_Rating      float64
# Meta_score       float64
# No_of_Votes        int64
# Overview          object
# Poster_Link       object
# Released_Year     object
# Runtime           object
# Series_Title      object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# Unnamed: 0         int64
# dtype: object

# %% [markdown]
# It can be seen that the Star attribute is repeating, therefore break up the Star1, Star2, Star3, and Star4 columns into separate rows.

# %%
df = pd.melt(df,
        id_vars = ['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
       'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'No_of_Votes', 'Gross'],
        value_vars = ['Star1', 'Star2', 'Star3', 'Star4'],
        var_name = 'Actor',
        value_name = 'Actor_Name').sort_values('Series_Title', ascending=True)

# %% [markdown]
# pd.melt() is useful if you need to define your variable and value column names manually.
#
# id_vars = a list of all the attributes to be ignored in the melt() action, it is mandatory if those attributes need to appear in the final table.
#
# value_vars = a list of all the attributes to consider in the melt() action.
#
# var_name = column name for all the attributes that will now be broken up and housed under one column.
#
# value_name = column name for the values of the broken up attributes.

# %%
df.head(10)
# Out:
#                                             Poster_Link          Series_Title  \
# 9535  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6993  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6994  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6995  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 1912  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 1911  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 9536  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 4454  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 4453  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 4452  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
#
#      Released_Year Certificate Runtime    Genre  IMDB_Rating  \
# 9535          2009          UA  95 min    Drama          7.7
# 6993          2009          UA  95 min   Comedy          7.7
# 6994          2009          UA  95 min    Drama          7.7
# 6995          2009          UA  95 min  Romance          7.7
# 1912          2009          UA  95 min    Drama          7.7
# 1911          2009          UA  95 min   Comedy          7.7
# 9536          2009          UA  95 min  Romance          7.7
# 4454          2009          UA  95 min  Romance          7.7
# 4453          2009          UA  95 min    Drama          7.7
# 4452          2009          UA  95 min   Comedy          7.7
#
#                                                Overview  Meta_score  \
# 9535  An offbeat romantic comedy about a woman who d...        76.0
# 6993  An offbeat romantic comedy about a woman who d...        76.0
# 6994  An offbeat romantic comedy about a woman who d...        76.0
# 6995  An offbeat romantic comedy about a woman who d...        76.0
# 1912  An offbeat romantic comedy about a woman who d...        76.0
# 1911  An offbeat romantic comedy about a woman who d...        76.0
# 9536  An offbeat romantic comedy about a woman who d...        76.0
# 4454  An offbeat romantic comedy about a woman who d...        76.0
# 4453  An offbeat romantic comedy about a woman who d...        76.0
# 4452  An offbeat romantic comedy about a woman who d...        76.0
#
#        Director  No_of_Votes       Gross  Actor            Actor_Name
# 9535  Marc Webb       472242  32,391,374  Star4    Chloë Grace Moretz
# 6993  Marc Webb       472242  32,391,374  Star3        Geoffrey Arend
# 6994  Marc Webb       472242  32,391,374  Star3        Geoffrey Arend
# 6995  Marc Webb       472242  32,391,374  Star3        Geoffrey Arend
# 1912  Marc Webb       472242  32,391,374  Star1       Zooey Deschanel
# 1911  Marc Webb       472242  32,391,374  Star1       Zooey Deschanel
# 9536  Marc Webb       472242  32,391,374  Star4    Chloë Grace Moretz
# 4454  Marc Webb       472242  32,391,374  Star2  Joseph Gordon-Levitt
# 4453  Marc Webb       472242  32,391,374  Star2  Joseph Gordon-Levitt
# 4452  Marc Webb       472242  32,391,374  Star2  Joseph Gordon-Levitt

# %% [markdown]
# After the column separation, the Actor column seems useless and may be deleted if necessary.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. Get rid of duplicated rows, if any.

# %%
df = df.drop_duplicates()

# %% [markdown]
# 2. Get rid of duplicated columns if any. A previous alphabetical printout of the column list already showed no duplicates.

# %% [markdown]
# 3. Fill all null values: In an automated pipeline the scripts are designed to deal with whatever issues may arise. Therefore there is no need to check for specific cases of nulls before filling them. Instead we determine the data type of each column and decide what to fill any nulls with. This ties in with the next transformation step which is...

# %% [markdown]
# # Data Validation

# %% [markdown]
# 1. Here we verify that values under a column fit the column's data type. Together with the previous step the script can be combined and designed as:
# - decide each column's data type
# - convert to decided data types if needed
# - fill the nulls under each column with appropriate defaults
# - flag any values that don't match the column data type

# %%
# Create a mapping of the decided data type for each column:
schema = {
            'Poster_Link': 'string',
            'Series_Title': 'string',
            'Released_Year': 'Int64',
            'Certificate': 'string',
            'Runtime': 'string',
            'Genre': 'string',
            'IMDB_Rating': 'float',
            'Overview': 'string',
            'Meta_score': 'float',
            'Director': 'string',
            'No_of_Votes': 'Int64',
            'Gross': 'Int64'
        }

# %%
# The Gross column is currently saved as a string data type, since we intend to convert it to
# an integer any commas must first be removed, otherwise it will throw an error.

df['Gross'] = df['Gross'].str.replace(',', '')

# %%
# Next convert each column to its preferred data type and flag an values not matching the data type (errors='coerce')

for col, dtype in schema.items():
    if dtype == 'Int64':
        df[col] = pd.to_numeric(df[col], errors="coerce").astype('Int64')
    elif dtype == 'float':
        df[col] = pd.to_numeric(df[col], errors="coerce")
    elif dtype == 'datetime':
        df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
# For efficiency group columns by dtype
str_cols = df.select_dtypes(include='object').columns
num_cols = df.select_dtypes(include='number').columns
bool_cols = df.select_dtypes(include='bool').columns

# Apply default fills for the data type groups
df[num_cols] = df[num_cols].fillna(0)
df[str_cols] = df[str_cols].fillna('NA')
df[bool_cols] = df[bool_cols].fillna(False)

# %% [markdown]
# 2. This is the point to check and address date format inconsistencies, if any e.g. 2025-10-29 vs 10/29/2025, correcting impossible dates (e.g. 2025-02-30) etc.
#
# This would normally fall under the data cleaning step but it is easier to run it at this step after data types have been confirmed, all error-values flagged, and all nulls have been filled.

# %% [markdown]
# 3. Next, verify the logic of existing dates, if any e.g. checking that end_date ≥ start_date, that all dates fall within a valid range, that timestamps match expected formats etc.

# %% [markdown]
# 4. Identify and separate the entities into their respective groups

# %%
movies = df[['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
       'Runtime', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
       'No_of_Votes', 'Gross']]
movies.head(5)
# Out:
#                                             Poster_Link          Series_Title  \
# 9535  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6993  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6994  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6995  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 1912  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
#
#      Released_Year Certificate Runtime  IMDB_Rating  \
# 9535          2009          UA  95 min          7.7
# 6993          2009          UA  95 min          7.7
# 6994          2009          UA  95 min          7.7
# 6995          2009          UA  95 min          7.7
# 1912          2009          UA  95 min          7.7
#
#                                                Overview  Meta_score  \
# 9535  An offbeat romantic comedy about a woman who d...        76.0
# 6993  An offbeat romantic comedy about a woman who d...        76.0
# 6994  An offbeat romantic comedy about a woman who d...        76.0
# 6995  An offbeat romantic comedy about a woman who d...        76.0
# 1912  An offbeat romantic comedy about a woman who d...        76.0
#
#        Director  No_of_Votes     Gross
# 9535  Marc Webb       472242  32391374
# 6993  Marc Webb       472242  32391374
# 6994  Marc Webb       472242  32391374
# 6995  Marc Webb       472242  32391374
# 1912  Marc Webb       472242  32391374

# %% [markdown]
# Next, ensure that there are no duplicated business keys. Here the business keys will be Series_Title and Released_Year.

# %%
movies = movies.drop_duplicates(subset=['Series_Title', 'Released_Year'], keep='first')

# %% [markdown]
# Finally, repeat the above step for each of the entity groups before loading them to their tables.

# %% [markdown]
# # Observation

# %% [markdown]
# After business key duplicates were removed from the movie dataset, there wwas still a duplicate found under the primary key (Series_Title), however if the business key doesn't confirm duplicates then such findings are not real duplicates rather data entry issues.

# %%
movies['Series_Title'][movies['Series_Title'].duplicated(keep=False)]
# Out:
# 2760    Drishyam
# 2883    Drishyam
# Name: Series_Title, dtype: object

# %%
movies[movies['Series_Title'] == 'Drishyam']
# Out:
#                                             Poster_Link Series_Title  \
# 2760  https://m.media-amazon.com/images/M/MV5BYmY3Mz...     Drishyam
# 2883  https://m.media-amazon.com/images/M/MV5BYmJhZm...     Drishyam
#
#      Released_Year Certificate  Runtime  IMDB_Rating  \
# 2760          2013           U  160 min          8.3
# 2883          2015          UA  163 min          8.2
#
#                                                Overview Meta_score  \
# 2760  A man goes to extreme lengths to save his fami...       50.0
# 2883  Desperate measures are taken by a man who trie...       50.0
#
#              Director  No_of_Votes    Gross
# 2760    Jeethu Joseph        30722       NA
# 2883  Nishikant Kamat        70367  739,478

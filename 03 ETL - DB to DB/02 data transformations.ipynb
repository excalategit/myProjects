# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql:///Source')

# %%
query = '''SELECT * FROM movies'''
df = pd.read_sql(query, engine)

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.sample(5)
# Out:
#      Unnamed: 0                                        Poster_Link  \
# 468         466  https://m.media-amazon.com/images/M/MV5BZGVmY2...
# 239         237  https://m.media-amazon.com/images/M/MV5BMTQ1Mj...
# 228         226  https://m.media-amazon.com/images/M/MV5BMGVmMW...
# 696         693  https://m.media-amazon.com/images/M/MV5BNzZlMT...
# 213         211  https://m.media-amazon.com/images/M/MV5BYzQxND...
#
#                                      Series_Title Released_Year Certificate  \
# 468                                Marriage Story          2019           U
# 239                                 Before Sunset          2004           R
# 228  Harry Potter and the Deathly Hallows: Part 2          2011          UA
# 696                              The Conversation          1974           U
# 213                   Ôkami kodomo no Ame to Yuki          2012           U
#
#      Runtime                      Genre  IMDB_Rating  \
# 468  137 min     Comedy, Drama, Romance          7.9
# 239   80 min             Drama, Romance          8.1
# 228  130 min  Adventure, Drama, Fantasy          8.1
# 696  113 min   Drama, Mystery, Thriller          7.8
# 213  117 min  Animation, Drama, Fantasy          8.1
#
#                                               Overview  Meta_score  \
# 468  Noah Baumbach's incisive and compassionate loo...        94.0
# 239  Nine years after Jesse and Celine first met, t...        90.0
# 228  Harry, Ron, and Hermione search for Voldemort'...        85.0
# 696  A paranoid, secretive surveillance expert has ...        85.0
# 213  After her werewolf lover unexpectedly dies in ...        71.0
#
#                  Director             Star1               Star2  \
# 468         Noah Baumbach       Adam Driver  Scarlett Johansson
# 239     Richard Linklater       Ethan Hawke         Julie Delpy
# 228           David Yates  Daniel Radcliffe         Emma Watson
# 696  Francis Ford Coppola      Gene Hackman         John Cazale
# 213         Mamoru Hosoda      Aoi Miyazaki         Takao Osawa
#
#                 Star3                  Star4  No_of_Votes        Gross
# 468       Julia Greer         Azhy Robertson       246644    2,000,000
# 239  Vernon Dobtcheff  Louise Lemoine Torrès       236311    5,820,649
# 228      Rupert Grint         Michael Gambon       764493  381,011,219
# 696    Allen Garfield       Frederic Forrest        98611    4,420,000
# 213       Haru Kuroki          Yukito Nishii        38803         None

# %% [markdown]
# # Data Restructuring

# %% [markdown]
# 1. Break up comma-separated values into rows.
#
# Apart from the Genre column, check if there are others columns containing comma-separated values.

# %%
for col in df:
    if df[col].astype(str).str.contains(',').any():
        print (col)
# Out:
# Poster_Link
# Series_Title
# Genre
# Overview
# Gross

# %%
df[['Poster_Link', 'Series_Title', 'Overview', 'Gross']].head(5)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  \
# 0  The Shawshank Redemption
# 1             The Godfather
# 2           The Dark Knight
# 3    The Godfather: Part II
# 4              12 Angry Men
#
#                                             Overview        Gross
# 0  Two imprisoned men bond over a number of years...   28,341,469
# 1  An organized crime dynasty's aging patriarch t...  134,966,411
# 2  When the menace known as the Joker wreaks havo...  534,858,444
# 3  The early life and career of Vito Corleone in ...   57,300,000
# 4  A jury holdout attempts to prevent a miscarria...    4,360,000

# %% [markdown]
# Further investigation shows that the presence of commas in other columns is not due to a case of multiple values separated by commas, therefore comma separation will be done for the Genre column alone.

# %%
df['Genre'] = df['Genre'].str.split(',')
df = df.explode('Genre')

# %%
df.head(10)
# Out:
#    Unnamed: 0                                        Poster_Link  \
# 0           0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1           1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 1           1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2           2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2           2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 2           2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3           3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 3           3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4           4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 4           4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime   Genre  \
# 0  The Shawshank Redemption          1994           A  142 min   Drama
# 1             The Godfather          1972           A  175 min   Crime
# 1             The Godfather          1972           A  175 min   Drama
# 2           The Dark Knight          2008          UA  152 min  Action
# 2           The Dark Knight          2008          UA  152 min   Crime
# 2           The Dark Knight          2008          UA  152 min   Drama
# 3    The Godfather: Part II          1974           A  202 min   Crime
# 3    The Godfather: Part II          1974           A  202 min   Drama
# 4              12 Angry Men          1957           U   96 min   Crime
# 4              12 Angry Men          1957           U   96 min   Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 2          9.0  When the menace known as the Joker wreaks havo...        84.0
# 3          9.0  The early life and career of Vito Corleone in ...        90.0
# 3          9.0  The early life and career of Vito Corleone in ...        90.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
# 4          9.0  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 2   Michael Caine      2303232  534,858,444
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000
# 4    John Fiedler       689845    4,360,000

# %% [markdown]
# 2. Check for repeating columns of the same attribute.
#
# Printing the list of columns alphabetically makes this easier to spot.

# %%
df.dtypes.sort_index()
# Out:
# Certificate       object
# Director          object
# Genre             object
# Gross             object
# IMDB_Rating      float64
# Meta_score       float64
# No_of_Votes        int64
# Overview          object
# Poster_Link       object
# Released_Year     object
# Runtime           object
# Series_Title      object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# Unnamed: 0         int64
# dtype: object

# %% [markdown]
# It can be seen that the Star attribute is repeating therefore break up the Star1, Star2, Star3, and Star4 columns into separate rows.

# %%
df = pd.melt(df,
        id_vars = ['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
       'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'No_of_Votes', 'Gross'],
        value_vars = ['Star1', 'Star2', 'Star3', 'Star4'],
        var_name = 'Actor',
        value_name = 'Actor_Name').sort_values('Series_Title', ascending=True)

# %% [markdown]
# pd.melt() is useful if you need to define your variable and value column names manually.
#
# id_vars = a list of all the attributes to ignore in the melt() action, it is mandatory if those attributes need to appear in the final table.
# value_vars = a list of all the attributes to consider in the melt() action.
# var_name = column name for all the attributes that will now be broken up and housed under one column.
# value_name = column name for the values of the broken up attributes.

# %%
df.head(10)
# Out:
#                                             Poster_Link          Series_Title  \
# 9535  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6993  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6994  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 6995  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 1912  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 1911  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 9536  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 4454  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 4453  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
# 4452  https://m.media-amazon.com/images/M/MV5BMTk5Mj...  (500) Days of Summer
#
#      Released_Year Certificate Runtime     Genre  IMDB_Rating  \
# 9535          2009          UA  95 min     Drama          7.7
# 6993          2009          UA  95 min    Comedy          7.7
# 6994          2009          UA  95 min     Drama          7.7
# 6995          2009          UA  95 min   Romance          7.7
# 1912          2009          UA  95 min     Drama          7.7
# 1911          2009          UA  95 min    Comedy          7.7
# 9536          2009          UA  95 min   Romance          7.7
# 4454          2009          UA  95 min   Romance          7.7
# 4453          2009          UA  95 min     Drama          7.7
# 4452          2009          UA  95 min    Comedy          7.7
#
#                                                Overview  Meta_score  \
# 9535  An offbeat romantic comedy about a woman who d...        76.0
# 6993  An offbeat romantic comedy about a woman who d...        76.0
# 6994  An offbeat romantic comedy about a woman who d...        76.0
# 6995  An offbeat romantic comedy about a woman who d...        76.0
# 1912  An offbeat romantic comedy about a woman who d...        76.0
# 1911  An offbeat romantic comedy about a woman who d...        76.0
# 9536  An offbeat romantic comedy about a woman who d...        76.0
# 4454  An offbeat romantic comedy about a woman who d...        76.0
# 4453  An offbeat romantic comedy about a woman who d...        76.0
# 4452  An offbeat romantic comedy about a woman who d...        76.0
#
#        Director  No_of_Votes       Gross  Actor            Actor_Name
# 9535  Marc Webb       472242  32,391,374  Star4    Chloë Grace Moretz
# 6993  Marc Webb       472242  32,391,374  Star3        Geoffrey Arend
# 6994  Marc Webb       472242  32,391,374  Star3        Geoffrey Arend
# 6995  Marc Webb       472242  32,391,374  Star3        Geoffrey Arend
# 1912  Marc Webb       472242  32,391,374  Star1       Zooey Deschanel
# 1911  Marc Webb       472242  32,391,374  Star1       Zooey Deschanel
# 9536  Marc Webb       472242  32,391,374  Star4    Chloë Grace Moretz
# 4454  Marc Webb       472242  32,391,374  Star2  Joseph Gordon-Levitt
# 4453  Marc Webb       472242  32,391,374  Star2  Joseph Gordon-Levitt
# 4452  Marc Webb       472242  32,391,374  Star2  Joseph Gordon-Levitt

# %% [markdown]
# After the column separation, the Actor column seems useless and may be deleted if necessary.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# 1. Check if the dataset contains nulls by displaying the count of nulls in each column.

# %%
df.isnull().sum()
# Out:
# Poster_Link         0
# Series_Title        0
# Released_Year       0
# Certificate       940
# Runtime             0
# Genre               0
# IMDB_Rating         0
# Overview            0
# Meta_score       1580
# Director            0
# No_of_Votes         0
# Gross            1728
# Actor               0
# Actor_Name          0
# dtype: int64

# %% [markdown]
# Replace all null values with appropriate values.

# %%
df['Certificate'] = df['Certificate'].fillna('NA')
df['Meta_score'] = df['Meta_score'].fillna('50.0')
df['Gross'] = df['Gross'].fillna('NA')

# %% [markdown]
# 2. Get rid of duplicated rows, if any.

# %%
df = df.drop_duplicates()

# %% [markdown]
# 3. Get rid of duplicated columns if any. A previous alphabetical printout of the column list already showed no duplicates.

# %% [markdown]
# 4. This is the point to check and address date format inconsistencies, if any.

# %% [markdown]
# # Data Validation

# %% [markdown]
# 1. Check that values under a column match the column's data type.

# %%
df.dtypes.sort_index()
# Out:
# Actor             object
# Actor_Name        object
# Certificate       object
# Director          object
# Genre             object
# Gross             object
# IMDB_Rating      float64
# Meta_score        object
# No_of_Votes        int64
# Overview          object
# Poster_Link       object
# Released_Year     object
# Runtime           object
# Series_Title      object
# dtype: object

# %% [markdown]
# Released_Year is of type string which is unusual. To investigate this, one trick is to try to convert the column to the correct data type then check if pandas throws any errors. In this case converting the column to int
# - df['Released_Year'].astype(int)
#
# threw an error and highlighted a string value 'PG' among the list of values. This value can now be removed or replaced.

# %%
df[df['Released_Year'] == 'PG']
# Out:
#                                              Poster_Link Series_Title  \
# 2454   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 4993   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 10077  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 10076  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 10075  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 2452   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 4995   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 4994   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 2453   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 7536   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 7535   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
# 7534   https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#       Released_Year Certificate  Runtime      Genre  IMDB_Rating  \
# 2454             PG           U  140 min    History          7.6
# 4993             PG           U  140 min  Adventure          7.6
# 10077            PG           U  140 min    History          7.6
# 10076            PG           U  140 min      Drama          7.6
# 10075            PG           U  140 min  Adventure          7.6
# 2452             PG           U  140 min  Adventure          7.6
# 4995             PG           U  140 min    History          7.6
# 4994             PG           U  140 min      Drama          7.6
# 2453             PG           U  140 min      Drama          7.6
# 7536             PG           U  140 min    History          7.6
# 7535             PG           U  140 min      Drama          7.6
# 7534             PG           U  140 min  Adventure          7.6
#
#                                                 Overview Meta_score  \
# 2454   NASA must devise a strategy to return Apollo 1...       77.0
# 4993   NASA must devise a strategy to return Apollo 1...       77.0
# 10077  NASA must devise a strategy to return Apollo 1...       77.0
# 10076  NASA must devise a strategy to return Apollo 1...       77.0
# 10075  NASA must devise a strategy to return Apollo 1...       77.0
# 2452   NASA must devise a strategy to return Apollo 1...       77.0
# 4995   NASA must devise a strategy to return Apollo 1...       77.0
# 4994   NASA must devise a strategy to return Apollo 1...       77.0
# 2453   NASA must devise a strategy to return Apollo 1...       77.0
# 7536   NASA must devise a strategy to return Apollo 1...       77.0
# 7535   NASA must devise a strategy to return Apollo 1...       77.0
# 7534   NASA must devise a strategy to return Apollo 1...       77.0
#
#          Director  No_of_Votes        Gross  Actor   Actor_Name
# 2454   Ron Howard       269197  173,837,933  Star1    Tom Hanks
# 4993   Ron Howard       269197  173,837,933  Star2  Bill Paxton
# 10077  Ron Howard       269197  173,837,933  Star4  Gary Sinise
# 10076  Ron Howard       269197  173,837,933  Star4  Gary Sinise
# 10075  Ron Howard       269197  173,837,933  Star4  Gary Sinise
# 2452   Ron Howard       269197  173,837,933  Star1    Tom Hanks
# 4995   Ron Howard       269197  173,837,933  Star2  Bill Paxton
# 4994   Ron Howard       269197  173,837,933  Star2  Bill Paxton
# 2453   Ron Howard       269197  173,837,933  Star1    Tom Hanks
# 7536   Ron Howard       269197  173,837,933  Star3  Kevin Bacon
# 7535   Ron Howard       269197  173,837,933  Star3  Kevin Bacon
# 7534   Ron Howard       269197  173,837,933  Star3  Kevin Bacon

# %% [markdown]
# Knowing the release year of Apollo 13 we can replace PG with 1995

# %%
df['Released_Year'] = df['Released_Year'].replace('PG', 1995)

# %% [markdown]
# 2. This is the point to verify the logic of existing dates, if any e.g.checking that end_date ≥ start_date etc.

# %% [markdown]
# 3. Identify and separate the entities into their respective groups

# %%
movies = df[['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
       'Runtime', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
       'No_of_Votes', 'Gross']]
movies
# Out:
#                                             Poster_Link  \
# 9535  https://m.media-amazon.com/images/M/MV5BMTk5Mj...
# 6993  https://m.media-amazon.com/images/M/MV5BMTk5Mj...
# 6994  https://m.media-amazon.com/images/M/MV5BMTk5Mj...
# 6995  https://m.media-amazon.com/images/M/MV5BMTk5Mj...
# 1912  https://m.media-amazon.com/images/M/MV5BMTk5Mj...
# ...                                                 ...
# 3073  https://m.media-amazon.com/images/M/MV5BYzQxND...
# 534   https://m.media-amazon.com/images/M/MV5BYzQxND...
# 533   https://m.media-amazon.com/images/M/MV5BYzQxND...
# 532   https://m.media-amazon.com/images/M/MV5BYzQxND...
# 3074  https://m.media-amazon.com/images/M/MV5BYzQxND...
#
#                      Series_Title Released_Year Certificate  Runtime  \
# 9535         (500) Days of Summer          2009          UA   95 min
# 6993         (500) Days of Summer          2009          UA   95 min
# 6994         (500) Days of Summer          2009          UA   95 min
# 6995         (500) Days of Summer          2009          UA   95 min
# 1912         (500) Days of Summer          2009          UA   95 min
# ...                           ...           ...         ...      ...
# 3073  Ôkami kodomo no Ame to Yuki          2012           U  117 min
# 534   Ôkami kodomo no Ame to Yuki          2012           U  117 min
# 533   Ôkami kodomo no Ame to Yuki          2012           U  117 min
# 532   Ôkami kodomo no Ame to Yuki          2012           U  117 min
# 3074  Ôkami kodomo no Ame to Yuki          2012           U  117 min
#
#       IMDB_Rating                                           Overview  \
# 9535          7.7  An offbeat romantic comedy about a woman who d...
# 6993          7.7  An offbeat romantic comedy about a woman who d...
# 6994          7.7  An offbeat romantic comedy about a woman who d...
# 6995          7.7  An offbeat romantic comedy about a woman who d...
# 1912          7.7  An offbeat romantic comedy about a woman who d...
# ...           ...                                                ...
# 3073          8.1  After her werewolf lover unexpectedly dies in ...
# 534           8.1  After her werewolf lover unexpectedly dies in ...
# 533           8.1  After her werewolf lover unexpectedly dies in ...
# 532           8.1  After her werewolf lover unexpectedly dies in ...
# 3074          8.1  After her werewolf lover unexpectedly dies in ...
#
#      Meta_score       Director  No_of_Votes       Gross
# 9535       76.0      Marc Webb       472242  32,391,374
# 6993       76.0      Marc Webb       472242  32,391,374
# 6994       76.0      Marc Webb       472242  32,391,374
# 6995       76.0      Marc Webb       472242  32,391,374
# 1912       76.0      Marc Webb       472242  32,391,374
# ...         ...            ...          ...         ...
# 3073       71.0  Mamoru Hosoda        38803          NA
# 534        71.0  Mamoru Hosoda        38803          NA
# 533        71.0  Mamoru Hosoda        38803          NA
# 532        71.0  Mamoru Hosoda        38803          NA
# 3074       71.0  Mamoru Hosoda        38803          NA
#
# [10164 rows x 11 columns]

# %% [markdown]
# Next, ensure that there are no duplicated business keys. Here the business keys will be Series_Title and Released_Year.

# %%
movies = movies.drop_duplicates(subset=['Series_Title', 'Released_Year'], keep='first')

# %% [markdown]
# Observation: After business key duplicates are removed, checking for duplicates on the primary key (Series_Title) still showed duplicates...

# %%
movies['Series_Title'].duplicated().any()
# Out:
# np.True_

# %% [markdown]
# Investigating further it appears that the second instance of the duplicate (looking at Released_Year) is a Part 2 of the first.

# %%
movies['Series_Title'][movies['Series_Title'].duplicated(keep=False)]
# Out:
# 2760    Drishyam
# 2883    Drishyam
# Name: Series_Title, dtype: object

# %%
movies[movies['Series_Title'] == 'Drishyam']
# Out:
#                                             Poster_Link Series_Title  \
# 2760  https://m.media-amazon.com/images/M/MV5BYmY3Mz...     Drishyam
# 2883  https://m.media-amazon.com/images/M/MV5BYmJhZm...     Drishyam
#
#      Released_Year Certificate  Runtime  IMDB_Rating  \
# 2760          2013           U  160 min          8.3
# 2883          2015          UA  163 min          8.2
#
#                                                Overview Meta_score  \
# 2760  A man goes to extreme lengths to save his fami...       50.0
# 2883  Desperate measures are taken by a man who trie...       50.0
#
#              Director  No_of_Votes    Gross
# 2760    Jeethu Joseph        30722       NA
# 2883  Nishikant Kamat        70367  739,478

# %% [markdown]
# Therefore the data can be updated accordingly.

# %% [markdown]
# However this is not a real duplicate. Ideally a duplicate is verified by checking using business keys e.g. here, with Series_Title and Released_Year. Since these attributes are not duplicated it cannot be considered a duplicate rather a data entry issue. This can be addressed using a separate validation script as an exception.

# %% [markdown]
# Finally, repeat the above step (pt.3) for each of the entity groups before loading them to their tables.
